# %% [markdown]
# # **TikTok Project**
# **Course 3 - Go Beyond the Numbers: Translate Data into Insights**

# %% [markdown]
# Your TikTok data team is still in the early stages of their latest project. So far, you’ve completed a project proposal and used Python to inspect and organize the TikTok dataset.
#
# Orion Rainier, a Data Scientist at TikTok, is pleased with the work you have already completed and is requesting your assistance with some Exploratory Data Analysis (EDA) and data visualization. The management team asked to see a Python notebook showing data structuring and cleaning, as well as any matplotlib/seaborn visualizations plotted to help us understand the data. At the very least, include a graph comparing claim counts to opinion counts, as well as boxplots of the most important variables (like “video duration,” “video like count,” “video comment count,” and “video view count”) to check for outliers. Also, include a breakdown of “author ban status” counts.
#
# Additionally, the management team has recently asked all EDA to include Tableau visualizations. Tableau visualizations are particularly helpful in status reports to the client and board members. For this data, create a Tableau dashboard showing a simple claims versus opinions count, as well as stacked bar charts of claims versus opinions for variables like video view counts, video like counts, video share counts, and video download counts. Make sure it is easy to understand to someone who isn’t data savvy, and remember that the assistant director is a person with visual impairments.
#
# You also notice a follow-up email from the Data Science Lead, Willow Jaffey. Willow suggests including an executive summary of your analysis to share with teammates.
#
# A notebook was structured and prepared to help you in this project. Please complete the following questions.

# %% [markdown]
# # **Course 3 End-of-course project: Exploratory data analysis**
#
# In this activity, you will examine data provided and prepare it for analysis. You will also design a professional data visualization that tells a story, and will help data-driven decisions for business needs.
#
# Please note that the Tableau visualization activity is optional, and will not affect your completion of the course. Completing the Tableau activity will help you practice planning out and plotting a data visualization based on a specific business need. The structure of this activity is designed to emulate the proposals you will likely be assigned in your career as a data professional. Completing this activity will help prepare you for those career moments.
# <br/>
#
# **The purpose** of this project is to conduct exploratory data analysis on a provided data set. Your mission is to continue the investigation you began in C2 and perform further EDA on this data with the aim of learning more about the variables. Of particular interest is information related to what distinguishes claim videos from opinion videos.
#
# **The goal** is to explore the dataset and create visualizations.
# <br/>
# *This activity has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration
# *   Data cleaning
#
#
# **Part 3:** Build visualizations
#
# **Part 4:** Evaluate and share results

# %% [markdown]
# Follow the instructions and answer the question below to complete the activity. Then, you will complete an executive summary using the questions listed on the PACE Strategy Document.
#
# Be sure to complete this activity before moving on. The next course item will provide you with a completed exemplar to compare to your own work.

# %% [markdown]
# # **Visualize a story in Tableau and Python**

# %% [markdown]
# <img src="images/Pace.png" width="100" height="100" align=left>
#
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## **PACE: Plan**
#
# Consider the questions in your PACE Strategy Document and those below where applicable to craft your response:
# 1. Identify any outliers:
#
#
# *   What methods are best for identifying outliers?
# *   How do you make the decision to keep or exclude outliers from any future models?

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE

# %% [markdown]
# ### **Task 1. Imports, links, and loading**
# Go to Tableau Public
# The following link will help you complete this activity. Keep Tableau Public open as you proceed to the next steps.
#
# Link to supporting materials:
# Public Tableau: https://public.tableau.com/s/. Note that the TikTok dataset can be downloaded directly from this notebook by going to "Lab Files" in the menu bar at the top of the page, clicking into the "/home/jovyan/work" folder, selecting `tiktok_dataset.csv`, and clicking "Download" above the list of files.
#
# For EDA of the data, import the packages that would be most helpful, such as `pandas`, `numpy`, `matplotlib.pyplot`, and `seaborn`.

# %%
# Import packages for data manipulation
import pandas as pd
import numpy as np
import csv

# Import packages for data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Then, load the dataset into a dataframe. Read in the data and store it as a dataframe object.
#
# **Note:** As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# Load dataset into dataframe
TikTok_df = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## **PACE: Analyze**
#
# Consider the questions in your PACE Strategy Document and those below where applicable to complete your code.

# %% [markdown]
# ### **Task 2a: Data exploration and cleaning**
#
# The first step is to assess your data. Check the Data Source page on Tableau Public to get a sense of the size, shape and makeup of the data set.
#
# Consider functions that help you understand and structure the data.
#
# *    `.head()`
# *    `.info()`
# *    `.describe()`
# *    `.groupby()`
# *    `.sort_values()`
#
# Consider the following questions as you work:
#
# What do you do about missing data (if any)? There are 298 missing data which are NaNs which existed in 7 measurable columns. These data would be irrelevant for further analysis due to missing results, thus deletion is proper.
#
# Are there data outliers? There are outliers in every numerical columns, totalling 7, considering the standard deviation mentioned in the dataset description.

# %%
# Display and examine the first few rows of the dataframe
TikTok_df.head(100)
# Out:
#       # claim_status    video_id  video_duration_sec  \
# 0     1        claim  7017666017                  59
# 1     2        claim  4014381136                  32
# 2     3        claim  9859838091                  31
# 3     4        claim  1866847991                  25
# 4     5        claim  7105231098                  19
# ..  ...          ...         ...                 ...
# 95   96        claim  6570169707                  50
# 96   97        claim  1386456170                  32
# 97   98        claim  4415434682                  16
# 98   99        claim  3490110525                  57
# 99  100        claim  8089681692                  49
#
#                              video_transcription_text verified_status  \
# 0   someone shared with me that drone deliveries a...    not verified
# 1   someone shared with me that there are more mic...    not verified
# 2   someone shared with me that american industria...    not verified
# ...

# %%
# Display and examine the last few rows of the dataframe
TikTok_df.tail()
# Out:
#            # claim_status    video_id  video_duration_sec  \
# 19377  19378          NaN  7578226840                  21
# 19378  19379          NaN  6079236179                  53
# 19379  19380          NaN  2565539685                  10
# 19380  19381          NaN  2969178540                  24
# 19381  19382          NaN  8132759688                  13
#
#       video_transcription_text verified_status author_ban_status  \
# 19377                      NaN    not verified            active
# 19378                      NaN    not verified            active
# 19379                      NaN        verified      under review
# 19380                      NaN    not verified            active
# 19381                      NaN    not verified            active
#
#        video_view_count  video_like_count  video_share_count  \
# 19377               NaN               NaN                NaN
# 19378               NaN               NaN                NaN
# ...

# %%
# Get the size of the data
TikTok_df.size
# Out:
# 232584

# %%
# Get the shape of the data
TikTok_df.shape
# Out:
# (19382, 12)

# %%
# Get basic information about the data
TikTok_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Generate a table of descriptive statistics
TikTok_df.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %%
# identify the number of missing data from the data from each column
missing_check = TikTok_df.isna().sum()
print(f"The following are the missing values from TikTok dataset:{missing_check}")
# Out:
# The following are the missing values from TikTok dataset:#                             0
# claim_status                298
# video_id                      0
# video_duration_sec            0
# video_transcription_text    298
# verified_status               0
# author_ban_status             0
# video_view_count            298
# video_like_count            298
# video_share_count           298
# video_download_count        298
# video_comment_count         298
# dtype: int64

# %%
# clean all NaNs
TikTok_df_cleaned = TikTok_df.dropna()
TikTok_df_cleaned.isna().sum()
# Out:
# #                           0
# claim_status                0
# video_id                    0
# video_duration_sec          0
# video_transcription_text    0
# verified_status             0
# author_ban_status           0
# video_view_count            0
# video_like_count            0
# video_share_count           0
# video_download_count        0
# video_comment_count         0
# dtype: int64

# %%
# check if there are any duplicated data in the data set
TikTok_df_cleaned.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Identify Outliers and Decide Whether to Delete or Not

# %%
def identify_outlier():
    column = str(input("Which column? "))

    print(f"\nAnalyzing column: {column}")
    print(TikTok_df_cleaned[column].describe())  # Print summary statistics

    # Calculate 25th percentile of the column
    percentile25 = TikTok_df_cleaned[column].quantile(0.25)
    # Calculate 75th percentile of the column
    percentile75 = TikTok_df_cleaned[column].quantile(0.75)
    # Calculate interquartile range (IQR)
    iqr = percentile75 - percentile25

    # Calculate upper and lower thresholds for outliers
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    print(f"\nLower limit is: {lower_limit}")
    print(f"Upper limit is: {upper_limit}")
    print(f"IQR is: {iqr}\n")
    print(TikTok_df_cleaned[TikTok_df_cleaned[column] < lower_limit])

    # Print all relevant values to assist with debugging
    print(f"25th percentile: {percentile25}")
    print(f"75th percentile: {percentile75}")

# %%
identify_outlier()
# Out:
# Which column? video_duration_sec
#
# Analyzing column: video_duration_sec
# count    19084.000000
# mean        32.423811
# std         16.226470
# min          5.000000
# 25%         18.000000
# 50%         32.000000
# 75%         47.000000
# max         60.000000
# Name: video_duration_sec, dtype: float64
#
# Lower limit is: -25.5
# Upper limit is: 90.5
# IQR is: 29.0
#
# Empty DataFrame
# Columns: [#, claim_status, video_id, video_duration_sec, video_transcription_text, verified_status, author_ban_status, video_view_count, video_like_count, video_share_count, video_download_count, video_comment_count]
# Index: []
# 25th percentile: 18.0
# 75th percentile: 47.0

# %% [markdown]
# ### **Task 2b. Assess data types**

# %% [markdown]
# In Tableau, staying on the data source page, double check the data types of the columns in the dataset. Refer to the dimensions and measures in Tableau.

# %% [markdown]
# Review the instructions linked in the previous Activity document to create the required Tableau visualization.

# %% [markdown]
# ### **Task 2c. Select visualization type(s)**

# %% [markdown]
# Select data visualization types that will help you understand and explain the data.
#
# Now that you know which data columns you’ll use, it is time to decide which data visualization makes the most sense for EDA of the TikTok dataset. What type of data visualization(s) would be most helpful? Consider the distribution of the data.
#
# * Line graph
# * Bar chart
# * Box plot
# * Histogram
# * Heat map
# * Scatter plot
# * A geographic map

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
#
# Consider the questions in your PACE Strategy Document to reflect on the Construct stage.

# %% [markdown]
# ### **Task 3. Build visualizations**
#
# Now that you have assessed your data, it’s time to plot your visualization(s).

# %% [markdown]
# #### **video_duration_sec**
#
# Create a box plot to examine the spread of values in the `video_duration_sec` column.

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
### YOUR CODE HERE ###
box = sns.boxplot(x=TikTok_df_cleaned['video_duration_sec'])
g = plt.gca()
plt.xlabel('Video Duration in Seconds')
plt.title('TikTok Video Duration Statistics');

# %% [markdown]
# Create a histogram of the values in the `video_duration_sec` column to further explore the distribution of this variable.

# %%
# Create a histogram

# Assuming 'TikTok_df_cleaned' is your DataFrame
# Group by 'video_duration_sec' to get the count of videos per duration
grouped_df = TikTok_df_cleaned.groupby('video_duration_sec').size().reset_index(name='count')

# Plotting the histogram using seaborn
plt.figure(figsize=(12, 7))
sns.histplot(data=grouped_df, x='video_duration_sec', weights='count', bins=30, kde=False)
plt.xlabel('Video Duration (sec)')
plt.ylabel('Number of Videos')
plt.title('Distribution of Video Durations')
plt.show()

# %% [markdown]
# **Question:** What do you notice about the duration and distribution of the videos? There are no fluctuations in the data as it shows a balanced spread of videos with durations between 10 to 60 seconds.

# %% [markdown]
# #### **video_view_count**
#
# Create a box plot to examine the spread of values in the `video_view_count` column.

# %%
# Create a boxplot to visualize distribution of `video_view_count`
### YOUR CODE HERE ###

box = sns.boxplot(x=TikTok_df_cleaned['video_view_count'])
g = plt.gca()
plt.xlabel('Video View Count')
plt.title('Video View Count Spread');

# %% [markdown]
# Create a histogram of the values in the `video_view_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
# Create a histogram

# Assuming 'TikTok_df_cleaned' is your DataFrame
# Group by 'video_duration_sec' to get the count of videos per duration
grouped_df = TikTok_df_cleaned.groupby('video_view_count').size().reset_index(name='count')

# Plotting the histogram using seaborn
plt.figure(figsize=(12, 7))
sns.histplot(data=grouped_df, x='video_view_count', weights='count', bins=30, kde=False)
plt.xlabel('Video Views')
plt.ylabel('Number of Videos')
plt.title('Distribution of Video View Counts')
plt.show()

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable? There is fluctuation in the data. There seems to be a massive amount of videos reported with less than 0.05+10x6 view counts.

# %% [markdown]
# #### **video_like_count**
#
# Create a box plot to examine the spread of values in the `video_like_count` column.

# %%
def readable_numbers(x):
    """Takes a large number and formats it into K, M to make it more readable"""
    if x >= le6:
        s = '{:1.1f}M'.format(x*le-6)
    else:
        s = '{:1.0f}K'.format(x*le-3)
    return s

# %%
# Create a boxplot to visualize distribution of `video_like_count`
### YOUR CODE HERE ###
box = sns.boxplot(x=TikTok_df_cleaned['video_like_count'])
g = plt.gca()
plt.xlabel('Video Like Count')
plt.title('Video Like Count Spread');

# %% [markdown]
# Create a histogram of the values in the `video_like_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
# Create a histogram

# Assuming 'TikTok_df_cleaned' is your DataFrame
# Group by 'video_duration_sec' to get the count of videos per duration
grouped_df = TikTok_df_cleaned.groupby('video_like_count').size().reset_index(name='count')

# Plotting the histogram using seaborn
plt.figure(figsize=(12, 7))
sns.histplot(data=grouped_df, x='video_like_count', weights='count', bins=5, kde=False)
plt.xlabel('Video Likes')
plt.ylabel('Number of Videos')
plt.title('Distribution of Video Like Counts')
plt.show()

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?

# %% [markdown]
# #### **video_comment_count**
#
# Create a box plot to examine the spread of values in the `video_comment_count` column.

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
### YOUR CODE HERE ###

box = sns.boxplot(x=TikTok_df_cleaned['video_comment_count'])
g = plt.gca()
plt.xlabel('Video Comment Count')
plt.title('Video Comments Spread');

# %% [markdown]
# Create a histogram of the values in the `video_comment_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
# Create a histogram

# Assuming 'TikTok_df_cleaned' is your DataFrame
# Group by 'video_duration_sec' to get the count of videos per duration
grouped_df = TikTok_df_cleaned.groupby('video_comment_count').size().reset_index(name='count')

# Plotting the histogram using seaborn
plt.figure(figsize=(12, 7))
sns.histplot(data=grouped_df, x='video_comment_count', weights='count', bins=5, kde=False)
plt.xlabel('Comment Count')
plt.ylabel('Number of Videos')
plt.title('Distribution of Video Comments')
plt.show()

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable? The distribution is

# %% [markdown]
# #### **video_share_count**
#
# Create a box plot to examine the spread of values in the `video_share_count` column.

# %%
# Create a boxplot to visualize distribution of `video_share_count`
### YOUR CODE HERE ###
def df_boxplot():
    column = str(input("Insert which column of the Dataframe: "))
    xlabel = str(input("insert the name of the x axis: "))
    title = str(input("insert the title of the visualisation: "))
    box = sns.boxplot(x=TikTok_df_cleaned[column])
    g = plt.gca()
    plt.xlabel(xlabel)
    plt.title(title)
    plt.show()

# %%
def df_hist():
    column = str(input("Insert which column of the Dataframe: "))
    xlabel = str(input("insert the name of the x axis: "))
    ylabel = str(input("insert the name of the y axis: "))
    title = str(input("insert the title of the visualisation: "))

    # Assuming 'TikTok_df_cleaned' is your DataFrame
    # Group by 'video_duration_sec' to get the count of videos per duration
    grouped_df = TikTok_df_cleaned.groupby(column).size().reset_index(name='count')

    # Plotting the histogram using seaborn
    plt.figure(figsize=(12, 7))
    sns.histplot(data=grouped_df, x=column, weights='count', bins=5, kde=False)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
df_boxplot()
# Out:
# Insert which column of the Dataframe: video_share_count
# insert the name of the x axis: Video Shared Count
# insert the title of the visualisation: Shared Video Count Spread

# %% [markdown]
# *Create* a histogram of the values in the `video_share_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
df_hist()
# Out:
# Insert which column of the Dataframe: video_share_count
# insert the name of the x axis: Video Shared
# insert the name of the y axis: Number of Videos
# insert the title of the visualisation: Video Shares Stats

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?

# %% [markdown]
# #### **video_download_count**
#
# Create a box plot to examine the spread of values in the `video_download_count` column.

# %%
# Create a boxplot to visualize distribution of `video_download_count`
### YOUR CODE HERE ###
df_boxplot()
# Out:
# Insert which column of the Dataframe: video_download_count
# insert the name of the x axis: Video Download Count
# insert the title of the visualisation: Spread of Video Downloads

# %% [markdown]
# Create a histogram of the values in the `video_download_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
df_hist()
# Out:
# Insert which column of the Dataframe: video_download_count
# insert the name of the x axis: Video Downloads
# insert the name of the y axis: Number of Videos Total
# insert the title of the visualisation: Video Downloads Stats

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?

# %% [markdown]
# #### **Claim status by verification status**
#
# Now, create a histogram with four bars: one for each combination of claim status and verification status.
#
# Supported by AI, prompt:
# *TikTok_df_cleaned.groupby('video_comment_count').size().reset_index(name='count') is it possible to group by 2 data in this code line? For example group by video_verification and video_claim*

# %%
# Create a histogram
# Assuming 'TikTok_df_cleaned' is your DataFrame
# Group by 'claim_status', then 'verified status' to get the count of videos per duration
grouped_df = TikTok_df_cleaned.groupby(['claim_status', 'verified_status']).size().reset_index(name='count')
grouped_df['combined_column'] = grouped_df['claim_status'].astype(str) + '_' + grouped_df['verified_status'].astype(str)

# Plotting the histogram using seaborn to visualise claims + verification status in video count terms.
plt.figure(figsize=(12, 7))
sns.histplot(data = grouped_df, x='combined_column', weights='count', bins=5, kde=False)
plt.xlabel('Claim and Verified Status')
plt.ylabel('Number of Videos')
plt.title('Distribution of Video Claims and Verification')
plt.show()

# %%
# 2nd way of plotting this histogram through seaborn
# assign x axis to claim status and group by verified status with the hue function of seaborn
# the dodge function is to separate the two groups
plt.figure(figsize=(7,4))
sns.histplot(data=TikTok_df_cleaned,
             x='claim_status',
             hue='verified_status',
             multiple='dodge',
             shrink=0.9)
plt.title('Claims by verification status histogram');

# %% [markdown]
# **Question:** What do you notice about the number of verified users compared to unverified? And how does that affect their likelihood to post opinions?
#
# Visualisation represents a trend in reports against unverified accounts in both categories of claims and opinions. Moreover, there is also a slight higher count of reports on verified accounts that are opinions over claims. **This means that most videos which the reports are accounted to were either of unverified accounts or highly of opinionated reports if verified.**

# %% [markdown]
# #### **Claim status by author ban status**
#
# The previous course used a `groupby()` statement to examine the count of each claim status for each author ban status. Now, use a histogram to communicate the same information.

# %%
# Create a histogram
# Assuming 'TikTok_df_cleaned' is your DataFrame
# Group by 'claim_status', then 'author_ban_status' to get the count of videos per duration
grouped_df = TikTok_df_cleaned.groupby(['claim_status', 'author_ban_status']).size().reset_index(name='count')
grouped_df['combined_column'] = grouped_df['claim_status'].astype(str) + '_' + grouped_df['author_ban_status'].astype(str)

# Plotting the histogram using seaborn to visualise claims + verification status in video count terms.
plt.figure(figsize=(12, 7))
sns.histplot(data = grouped_df, x='combined_column', weights='count', multiple = 'dodge', bins=5, kde=False)
plt.xlabel('Claim, Ban Status')
plt.ylabel('Number of Videos')
plt.title('Claims per Author Ban Status Distribution')
plt.show()

# %%
# 2nd way of plotting the histogram without separately grouping the columns
# Utilise hue_order to categorise each data from the author ban status column in grouped order
# Utilise the colour palette function to assign each column with a specific colour

fig = plt.figure(figsize=(7,4))
sns.histplot(data = TikTok_df_cleaned, x='claim_status', hue='author_ban_status',
             multiple='dodge',
             hue_order=['active', 'under review', 'banned'],
             shrink=0.9,
             palette={'active':'green', 'under review':'orange', 'banned':'red'},
             alpha=0.5)
plt.title('Claim status by author ban status - counts');

# %% [markdown]
# **Question:** What do you notice about the number of active authors compared to banned authors for both claims and opinions?
#
# For both claims and opinions, there are many more active authors than banned authors or authors under review; however, the proportion of active authors is far greater for opinion videos than for claim videos. Moreover, it seems that authors who post claim videos are more likely to come under review and/or get banned. While far lower than those of the active authors, the number of non-active authors

# %% [markdown]
# #### **Median view counts by ban status**
#
# Create a bar plot with three bars: one for each author ban status. The height of each bar should correspond with the median number of views for all videos with that author ban status.

# %%
# Second way to visualise the bar plot, but with different colours for clear distinction of each group data
# Calculate medians for each 'author_ban_status'
# Set median to numeric_only to prevent any NA data to be counted as a median (however this only applies to dirty/uncleaned data)
median_view_counts = TikTok_df_cleaned.groupby('author_ban_status')['video_view_count'].median(numeric_only=True).reset_index()

# Plot the bar plot
# Set visual order from active to banned for a progressive status timeline throughout report to ban
plt.figure(figsize=(7, 4))
sns.barplot(data=median_view_counts,
            x='author_ban_status',
            y='video_view_count',
            palette={'active':'green', 'under review':'orange', 'banned':'red'},
            order=['active', 'under review', 'banned'],
            alpha=0.5)
plt.title('Medians of View Count per Author Ban Status')
plt.xlabel('Author Ban Status')
plt.ylabel('Median View Count')
plt.show()
# Out:
# <ipython-input-49-f2f3884f4f01>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=median_view_counts,

# %% [markdown]
# **Question:** What do you notice about the median view counts for non-active authors compared to that of active authors? Based on that insight, what variable might be a good indicator of claim status?
#
# The barrier between the median view counts of non-active (under-review and banned) are rather far distanced and aggregated than the active status. Moreover, there was surprisingly a higher median for author with banned status than those of the ones under review. These are surprising indicators which define how video_view_count was a good indicator for claim status.

# %%
# Create a function for the purpose of descriptive data analysis
def analyse_data():
    column1 = str(input("Which column data would you like to analyse based on their view count? "))
    column2 = str(input("Which column for them to be categorised by? "))

    # Create a list of unique categories
    categories = TikTok_df_cleaned[column2].unique()

    # Generate random colors for each category
    np.random.seed(150)  # For reproducibility
    random_colors = np.random.rand(len(categories), 3)

    # Create a dictionary mapping each category to a color
    palette = {category: color for category, color in zip(categories, random_colors)}

    # Plot
    plt.figure(figsize=(7,4))
    sns.barplot(data=TikTok_df_cleaned,
                x=column1,
                y='video_view_count',
                hue=column2,
                palette=palette,
                alpha=0.5)
    plt.title('View Count by Claim Status and Author Ban Status')
    plt.xlabel('Claim Status')
    plt.ylabel('Video View Count')
    plt.show()

    print(f"\nAnalyzing column: {column1}")
    print(TikTok_df_cleaned[column1].info())

# %%
# Calculate the median view count for claim status.
analyse_data()
# Out:
# Which column data would you like to analyse based on their view count? claim_status
# Which column for them to be categorised by? author_ban_status
# Analyzing column: claim_status
# <class 'pandas.core.series.Series'>
# Index: 19084 entries, 0 to 19083
# Series name: claim_status
# Non-Null Count  Dtype
# --------------  -----
# 19084 non-null  object
# dtypes: object(1)
# memory usage: 298.2+ KB
# None

# %%
def analyse_data2():
  data = TikTok_df_cleaned.groupby('claim_status')['video_view_count'].median()
  fig = plt.figure(figsize=(3,3))
  plt.pie(TikTok_df_cleaned.groupby('claim_status')['video_view_count'].sum(), labels=['claim', 'opinion'])
  plt.title('Total views by video claim status')

  return data

# %% [markdown]
# #### **Total views by claim status**
#
# Create a pie graph that depicts the proportions of total views for claim videos and total views for opinion videos.

# %%
analyse_data2()
# Out:
# claim_status
# claim      501555.0
# opinion      4953.0
# Name: video_view_count, dtype: float64

# %% [markdown]
# **Question:** What do you notice about the overall view count for claim status?
#
# The number of view count for claim videos far overgrown opinion videos. The claim status variables would not be great indicator for analysis as they have a far too great of a distance to compare between each other. There could only be a comparison of ban status within each group if an analysis were to be carried out. To support this argument, The differences in between each category of claim status is also barely seen.

# %% [markdown]
# ### **Task 4. Determine outliers**
#
# When building predictive models, the presence of outliers can be problematic. For example, if you were trying to predict the view count of a particular video, videos with extremely high view counts might introduce bias to a model. Also, some outliers might indicate problems with how data was captured or recorded.
#
# The ultimate objective of the TikTok project is to build a model that predicts whether a video is a claim or opinion. The analysis you've performed indicates that a video's engagement level is strongly correlated with its claim status. There's no reason to believe that any of the values in the TikTok data are erroneously captured, and they align with expectation of how social media works: a very small proportion of videos get super high engagement levels. That's the nature of viral content.
#
# Nonetheless, it's good practice to get a sense of just how many of your data points could be considered outliers. The definition of an outlier can change based on the details of your project, and it helps to have domain expertise to decide a threshold. You've learned that a common way to determine outliers in a normal distribution is to calculate the interquartile range (IQR) and set a threshold that is 1.5 * IQR above the 3rd quartile.
#
# In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than it would be if you used the 3rd quartile.
#
# Write a for loop that iterates over the column names of each count variable. For each iteration:
# 1. Calculate the IQR of the column
# 2. Calculate the median of the column
# 3. Calculate the outlier threshold (median + 1.5 * IQR)
# 4. Calculate the numer of videos with a count in that column that exceeds the outlier threshold
# 5. Print "Number of outliers, {column name}: {outlier count}"
#
# ```
# Example:
# Number of outliers, video_view_count: ___
# Number of outliers, video_like_count: ___
# Number of outliers, video_share_count: ___
# Number of outliers, video_download_count: ___
# Number of outliers, video_comment_count: ___
# ```

# %%
# Create a function to identify outliers
def identify_outlier():
    count_cols = ['video_view_count',
              'video_like_count',
              'video_share_count',
              'video_download_count',
              'video_comment_count',
              ]
    for column in count_cols:
      # Calculate 25th percentile of the column
      percentile25 = TikTok_df_cleaned[column].quantile(0.25)
      # Calculate 75th percentile of the column
      percentile75 = TikTok_df_cleaned[column].quantile(0.75)
      # Calculate interquartile range (IQR)
      iqr = percentile75 - percentile25

      median = TikTok_df_cleaned[column].median()
      # Calculate outlier threshold (median + 1.5 * IQR)
      outlier_threshold = median + 1.5 * iqr

      # Print all relevant values to assist with debugging
      outlier_count = (TikTok_df_cleaned[column] > outlier_threshold).sum()
      print(f'Number of outliers, {column}:', outlier_count)

# %%
identify_outlier()
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %% [markdown]
# #### **Scatterplot**

# %%
# Create a scatterplot function to look at grouped data by Hue
def scatterplot_data(data):
  column1 = str(input("Which column would you like to analyse by? "))
  column2 = str(input("Which column to compare it by? "))
  column3 = str(input("Which category would you like this column to be in (column)?"))

  sns.scatterplot(x=data[column1], y=data[column2],
                  hue=data[column3], s=10, alpha=.5)
  plt.show()

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'
scatterplot_data(TikTok_df_cleaned)
# Out:
# Which column would you like to analyse by? video_view_count
# Which column to compare it by? video_like_count
# Which category would you like this column to be in (column)?claim_status

# %% [markdown]
# Here's a brief explanation of the key parameters used in the code:
#
# x: The data for the x-axis, in this case, video_view_count.
#
# y: The data for the y-axis, in this case, video_like_count.
#
# hue: The data used to color the markers, in this case, claim_status.
#
# s: The size of the markers, set to 10.
#
# alpha: The transparency level of the markers, set to 0.3 (where 0 is fully transparent and 1 is fully opaque).

# %% [markdown]
# ### Explanation
# There seems to be more data crumbled in the lower view and like count for either opinion or claim category. This could either mean that there tend to be more videos with lower view and like count in the dataset or these are ineffective choice of variables for indicators in the data.

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
opinion_df = TikTok_df_cleaned[TikTok_df_cleaned['claim_status'] == 'opinion']

scatterplot_data(opinion_df)
# Out:
# Which column would you like to analyse by? video_view_count
# Which column to compare it by? video_like_count
# Which category would you like this column to be in (column)?claim_status

# %% [markdown]
# You can do a scatterplot in Tableau Public as well, which can be easier to manipulate and present. If you'd like step by step instructions, you can review the instructions linked in the previous Activity page.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
#
# Consider the questions in your PACE Strategy Document to reflect on the Execute stage.

# %% [markdown]
# ### **Task 5a. Results and evaluation**
#
# Having built visualizations in Tableau and in Python, what have you learned about the dataset? What other questions have your visualizations uncovered that you should pursue?
#
# ***Pro tip:*** Put yourself in your client's perspective, what would they want to know?
#
# Use the following code cells to pursue any additional EDA. Also use the space to make sure your visualizations are clean, easily understandable, and accessible.
#
# ***Ask yourself:*** Did you consider color, contrast, emphasis, and labeling?

# %% [markdown]
# I have learned that in order to generate useful information out of raw data, an analyst is required to effectively choose the correct data to be analysed and grouped by. For example, it would be ineffective to analyse indicators categorised by ban status by looking at video views/video likes grouped by claims. The aggregation and gap between the claimed and opinionated videos are way to narrow for an effective analysis. This could be more effective by focusing on specific group such as OPINIONS or CLAIMS only.
#
# Moreover, it is also important for an analyst to pick their choice of visualisation effectively. Without the right visualisation to use, the report would be less meaningful and indicators would be less presentable, especially to people with lesser knowledge on social media data such as customer service or finance officers. For example, utilising pie chart would have been meaningless and less impactful to visualise the relationship between video likes and views since both are two uncategorisable data, unlike claims or ban status.
#
# My other questions are would it be more effective to create a single-use code that is capable to fulfil each analysis, followed by printed-in notifications and visualisation.
#
# My client would likely want to know the relationship between the qualitative and quantitative data of the dataset such as the status and the various social media engagement numbers. For instance, the relationship between likes and views based on author ban, claim, or verification status. There could be more functions to be made to allow others to carry out these analysis without the need to create new code lines for each.

# %% [markdown]
# ### **Task 5b. Conclusion**
# *Make it professional and presentable*
#
# You have visualized the data you need to share with the director now. Remember, the goal of a data visualization is for an audience member to glean the information on the chart in mere seconds.
#
# *Questions to ask yourself for reflection:*
# Why is it important to conduct Exploratory Data Analysis? What other visuals could you create?

# %% [markdown]
# EDA is important because ...
#
# ==> ENTER YOUR RESPONSES HERE
#
# Visualizations helped me understand ..
#
# ==> ENTER YOUR RESPONSES HERE

# %% [markdown]
# You’ve now completed a professional data visualization according to a business need. Well done! Be sure to save your work as a reference for later work in Tableau.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
